# %%
name = input("Nhập tên: ")

name = name.strip()          # bỏ khoảng trắng 2 đầu
name = " ".join(name.split()) # chỉ còn 1 khoảng trắng giữa các từ
name = name.title()           # viết hoa chữ cái đầu

print(name)
# Out:
# Ạkashfkjas
